# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\com_bike_dataset.csv")

# %%
df=df.loc[370:]

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df
# Out:
#      Unnamed: 0   Manufacturer                                 Model  \
# 370  371.308987           Eeve                         4U(standard)'
# 371  372.311949           Eeve                       wind(standard)'
# 372  373.314912           Eeve                      Atreo(standard)'
# 373  374.317874           Eeve                      Ahava(standard)'
# 374  375.320837           Eeve                            Xeniaa(2)'
# 375  376.323799           Eeve                     Xeniaa(standard)'
# 376  377.326761         Evolet                       Derby(Classic)'
# 377  378.329724         Evolet                            Derby(EZ)'
# 378  379.332686         Evolet                       Polo (Classic)'
# 379  380.335649         Evolet                            Polo (EZ)'
# 380  381.338611         Evolet                       Pony (Classic)'
# 381  382.341574         Evolet                            Pony (EZ)'
# 382  383.344536           Hero       Electric NYX HX (Dual Battery)'
# ...

# %%
df.rename(columns={'Manufacturer':'Manufacturer',	'Engine_Capacity(CC)':'Engine_Capacity',	'Mileage(kmpl)':'Mileage',	'Weight(Kg)':'Weight',	'Fuel_Capacity(Ltrs)':'Fuel_Capacity',		'Riding_range(kms)':'Riding_range'	,'Charging_time(Hrs)':'Charging_time'},inplace=True)

# %%
df
# Out:
#      Unnamed: 0   Manufacturer                                 Model  \
# 370  371.308987           Eeve                         4U(standard)'
# 371  372.311949           Eeve                       wind(standard)'
# 372  373.314912           Eeve                      Atreo(standard)'
# 373  374.317874           Eeve                      Ahava(standard)'
# 374  375.320837           Eeve                            Xeniaa(2)'
# 375  376.323799           Eeve                     Xeniaa(standard)'
# 376  377.326761         Evolet                       Derby(Classic)'
# 377  378.329724         Evolet                            Derby(EZ)'
# 378  379.332686         Evolet                       Polo (Classic)'
# 379  380.335649         Evolet                            Polo (EZ)'
# 380  381.338611         Evolet                       Pony (Classic)'
# 381  382.341574         Evolet                            Pony (EZ)'
# 382  383.344536           Hero       Electric NYX HX (Dual Battery)'
# ...

# %%
df.to_csv(r'C:\Users\Admin\Desktop\project\bike_datset_3.csv')

# %%
df.isnull().sum()
# Out:
# Manufacturer             0
# Model                    0
# Engine_Capacity(CC)    104
# Mileage(kmpl)          171
# Weight(Kg)              47
# Fuel_Capacity(Ltrs)    115
# Top_speed               22
# Prices                   0
# Rating                  44
# Riding_range(kms)      299
# Charging_time(Hrs)     326
# dtype: int64

# %%
plt.figure(figsize=12,10),dpi=150
